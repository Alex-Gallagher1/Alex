# %%
#File: final_project.ipynb
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as opt
import pandas as pd

# %%
df = pd.read_csv('asu.tsv', sep=';', comment ='#')
df = df.iloc[2:]
df.head(40) # By default the data has many galaxies as specified b the name column so I have to go through and clean the data
# Out:
#           Name  sma     ell   muFUV cumuFUV   muNUV cumuNUV      FN sma36  \
# 2   ESO013-016    6   0.333  22.847  18.147  22.851  18.005  -0.005     8
# 3   ESO013-016   12   0.333  23.764  16.856  23.370  16.662   0.394    16
# 4   ESO013-016   18   0.333  24.074  16.431  23.786  16.146   0.288    24
# 5   ESO013-016   24   0.333  24.049  15.965  23.777  15.712   0.272    32
# 6   ESO013-016   30   0.333  24.338  15.589  24.038  15.329   0.300    40
# 7   ESO013-016   36   0.333  24.613  15.372  24.292  15.113   0.322    48
# 8   ESO013-016   42   0.333  24.734  15.189  24.590  14.934   0.144    56
# 9   ESO013-016   48   0.333  25.146  15.046  24.887  14.783   0.259    64
# 10  ESO013-016   54   0.333  25.650  14.944  25.573  14.694   0.077    72
# 11  ESO013-016   60   0.333  26.543  14.892  26.215  14.646   0.328    80
# 12  ESO013-016   66   0.333  27.453  14.867  26.684  14.617   0.769    87
# 13  ESO013-016   72   0.333  28.437  14.858  27.459  14.595   0.978    95
# ...

# %%
#Definding the model I will be using to fit the data to
def I_fit(r, Ie, re, n):
    """
    This function defines the intensity of a galaxy as a function of the radius

    Parameters
    r - distance from center
    Ie - half light intesity , which is the intesnity which captures half the light of the galaxy
    re - radius at hwich half the light is captured
    n - sersic index, determines type of galaxy
    """
    I = Ie * np.exp((r/re)**(1/n))
    return I

r =
